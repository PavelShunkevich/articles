# %% [markdown]
# # Article: http

# %%
## Import libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

np.random.seed(42)

# %%
#Screensaver picture

data1 = np.random.normal(loc=50, scale=15, size=100)
data2 = np.random.normal(loc=70, scale=10, size=100)
data3 = np.random.normal(loc=60, scale=20, size=100)
data = [data1, data2, data3]

palette = ["#a8dadc", "#457b9d", "#77ACF1"]

plt.figure(figsize=(12, 8))
sns.boxplot(data=data, palette=palette)
plt.savefig("boxplot_pastel.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

data = np.random.normal(loc=0, scale=1, size=2000)

fig, (ax_box, ax_dist) = plt.subplots(nrows=2, sharex=True,  figsize=(12, 8))  # Увеличенный размер для лучшей читаемости

box_plot_data = ax_box.boxplot(data, vert=False,
                            medianprops=dict(color="black"))
ax_box.set(yticks=[], xlabel="")

ax_dist.hist(data, bins=30, density=True, color='skyblue', edgecolor='black')
ax_dist.set_ylabel("Density")

stats_data = {}
for key, val in box_plot_data.items():
    stats_data[key] = [item.get_xdata() for item in val]
q1 = stats_data['boxes'][0][0]
q3 = stats_data['boxes'][0][2]
median = stats_data['medians'][0][0]
whisker_lower = stats_data['whiskers'][0][1]
whisker_upper = stats_data['whiskers'][1][1]


ax_dist.axvline(q1, color='r', linestyle='--', label='Q1', linewidth=3)
ax_dist.axvline(median, color='g', linestyle='-', label='Median', linewidth=3)
ax_dist.axvline(q3, color='r', linestyle='--', label='Q3', linewidth=3)
ax_dist.axvline(whisker_lower, color='b', linestyle=':', label='Whisker Lower', linewidth=3)
ax_dist.axvline(whisker_upper, color='b', linestyle=':', label='Whisker Upper', linewidth=3)

# Annotations
arrowprops = dict(arrowstyle='->', color='black', linewidth=1.5)
text_offset_x = 0.05 * (ax_box.get_xlim()[1] - ax_box.get_xlim()[0])
text_offset_y = 0.1
fontsize = 13

ax_box.annotate('1. Median', xy=(median, 0.93), xytext=(median + 0, 0.93 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('2. Q1', xy=(q1, 1.07), xytext=(q1 - text_offset_x, 1.07 + text_offset_y),
                    arrowprops=arrowprops, ha='right', va='bottom', fontsize=fontsize)
ax_box.annotate('3. Q3', xy=(q3, 1.07), xytext=(q3 + text_offset_x, 1.07 + text_offset_y),
                    arrowprops=arrowprops, ha='left', va='bottom', fontsize=fontsize)
ax_box.annotate('5. Outliers', xy=(whisker_lower-0.3, 0.95), xytext=(whisker_lower-0.3,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('5. Outliers', xy=(whisker_upper+0.3, 0.95), xytext=(whisker_upper+0.3,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('6.1. Whisker Lower', xy=(whisker_lower, 0.95), xytext=(whisker_lower + text_offset_x,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='left', va='top', fontsize=fontsize)
ax_box.annotate('6.2. Whisker Upper', xy=(whisker_upper, 0.95), xytext=(whisker_upper - text_offset_x,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='right', va='top', fontsize=fontsize)

ax_dist.set(xticks=[], xlabel="") 
plt.tight_layout()
plt.savefig("boxplot_norm_annotated.png")  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

data = np.random.normal(loc=0, scale=1, size=2000)

fig, (ax_box, ax_dist) = plt.subplots(nrows=2, sharex=True,  figsize=(7.8, 4.4))  # Увеличенный размер для лучшей читаемости

box_plot_data = ax_box.boxplot(data, vert=False,
                            medianprops=dict(color="black"))
ax_box.set(yticks=[], xlabel="")

ax_dist.hist(data, bins=30, density=True, color='skyblue', edgecolor='black')
ax_dist.set_ylabel("Density")

stats_data = {}
for key, val in box_plot_data.items():
    stats_data[key] = [item.get_xdata() for item in val]
q1 = stats_data['boxes'][0][0]
q3 = stats_data['boxes'][0][2]
median = stats_data['medians'][0][0]
whisker_lower = stats_data['whiskers'][0][1]
whisker_upper = stats_data['whiskers'][1][1]


ax_dist.axvline(q1, color='r', linestyle='--', label='Q1', linewidth=3)
ax_dist.axvline(median, color='g', linestyle='-', label='Median', linewidth=3)
ax_dist.axvline(q3, color='r', linestyle='--', label='Q3', linewidth=3)
ax_dist.axvline(whisker_lower, color='b', linestyle=':', label='Whisker Lower', linewidth=3)
ax_dist.axvline(whisker_upper, color='b', linestyle=':', label='Whisker Upper', linewidth=3)

# Annotations
arrowprops = dict(arrowstyle='->', color='black', linewidth=1.5)
text_offset_x = 0.05 * (ax_box.get_xlim()[1] - ax_box.get_xlim()[0])
text_offset_y = 0.1
fontsize = 8

ax_box.annotate('1. Median', xy=(median, 0.93), xytext=(median + 0, 0.93 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('2. Q1', xy=(q1, 1.07), xytext=(q1 - text_offset_x, 1.07 + text_offset_y),
                    arrowprops=arrowprops, ha='right', va='bottom', fontsize=fontsize)
ax_box.annotate('3. Q3', xy=(q3, 1.07), xytext=(q3 + text_offset_x, 1.07 + text_offset_y),
                    arrowprops=arrowprops, ha='left', va='bottom', fontsize=fontsize)
ax_box.annotate('5. Outliers', xy=(whisker_lower-0.3, 0.95), xytext=(whisker_lower-0.3,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('5. Outliers', xy=(whisker_upper+0.3, 0.95), xytext=(whisker_upper+0.3,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='center', va='top', fontsize=fontsize)
ax_box.annotate('6.1. Whisker Lower', xy=(whisker_lower, 0.95), xytext=(whisker_lower + text_offset_x,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='left', va='top', fontsize=fontsize)
ax_box.annotate('6.2. Whisker Upper', xy=(whisker_upper, 0.95), xytext=(whisker_upper - text_offset_x,  0.95 - text_offset_y),
                    arrowprops=arrowprops, ha='right', va='top', fontsize=fontsize)

ax_dist.set(xticks=[], xlabel="") 
plt.tight_layout()
plt.savefig("boxplot_norm_annotated_mini.png")  
plt.show()

# %% [markdown]
# # Main elements

# %%
import numpy as np 

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем медиану
median = np.median(data)
  
print("Список : ", data)  
print("Медиана списка : ", median)
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# Медиана списка :  21.0

# %%
import numpy as np

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем Q1
Q1 = np.quantile(data, 0.25)

print("Список : ", data)  
print(f"Q1 (25-й процентиль): {Q1}")
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# Q1 (25-й процентиль): 15.75

# %%
import numpy as np

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем Q3
Q3 = np.quantile(data, 0.75)

print("Список : ", data)  
print(f"Q3 (75-й процентиль): {Q3}")
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# Q3 (75-й процентиль): 28.75

# %%
import numpy as np

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем IQR
Q1 = np.quantile(data, 0.25)
Q3 = np.quantile(data, 0.75)
IQR = Q3 - Q1

print("Список : ", data)  
print(f"IQR (Межквартильный Диапазон): {IQR}")
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# IQR (Межквартильный Диапазон): 13.0

# %%
import numpy as np

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем Q1, Q3 и IQR
Q1 = np.quantile(data, 0.25)
Q3 = np.quantile(data, 0.75)
IQR = Q3 - Q1

# Определяем границы для выбросов
upper_outlier_threshold = Q3 + 1.5 * IQR
lower_outlier_threshold = Q1 - 1.5 * IQR

# Находим верхний ус (максимальное значение, не превышающее верхнюю границу)
upper_whisker = data[data <= upper_outlier_threshold].max()

# Находим нижний ус (минимальное значение, не меньшее нижней границы)
lower_whisker = data[data >= lower_outlier_threshold].min()

print("Список : ", data)
print(f"Верхний ус: {upper_whisker}")
print(f"Нижний ус: {lower_whisker}")
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# Верхний ус: 40
# Нижний ус: 10

# %%
import numpy as np

# Набор данных
data = np.array([10, 12, 15, 18, 20, 22, 25, 30, 40, 70])

# Вычисляем Q1, Q3 и IQR
Q1 = np.quantile(data, 0.25)
Q3 = np.quantile(data, 0.75)
IQR = Q3 - Q1

# Определяем границы для выбросов
upper_outlier_threshold = Q3 + 1.5 * IQR
lower_outlier_threshold = Q1 - 1.5 * IQR

# Находим выбросы
outliers = data[(data < lower_outlier_threshold) | (data > upper_outlier_threshold)]


print("Список : ", data)
print(f"Верхняя граница выбросов: {upper_outlier_threshold}")
print(f"Нижняя граница выбросов: {lower_outlier_threshold}")
print(f"Выбросы: {outliers}")
# Out:
# Список :  [10 12 15 18 20 22 25 30 40 70]
# Верхняя граница выбросов: 48.25
# Нижняя граница выбросов: -3.75
# Выбросы: [70]

# %% [markdown]
# # How to interpret a boxplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# Создаем искусственные данные о продажах автомобилей
data = {'Toyota': np.random.normal(loc=150, scale=25, size=24),
        'Honda': np.random.normal(loc=130, scale=20, size=24),
        'Ford': np.random.normal(loc=100, scale=30, size=24),
        'BMW': np.random.normal(loc=80, scale=15, size=24),
        'Tesla': np.random.normal(loc=90, scale=20, size=24)}
# Добавляем выбросы
data['Ford'][0] = 20.1
data['Ford'][1] = 30.312
data['Tesla'][1] = 150.112

# Создаем DataFrame
data = pd.DataFrame(data)
data.head()
# Out:
#        Toyota       Honda        Ford         BMW       Tesla
# 0  162.417854  119.112346   20.100000   79.462609   95.922406
# 1  146.543392  132.218452   30.312000  103.469655  150.112000
# 2  166.192213  106.980128  109.722519   40.703823   90.102269
# 3  188.075746  137.513960   88.447532   92.328538   85.308257
# 4  144.146166  117.987226   79.692340   81.305706   61.692585

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))  # Увеличим размер графика для лучшей читаемости
plt.boxplot(data, labels=data.columns)
# sns.boxplot(data=data)  # Используем sns.boxplot с вашими данными
plt.title("Сравнение продаж автомобилей разных марок (за 24 месяца)")
plt.ylabel("Количество проданных автомобилей")
plt.grid(True)
plt.show()
# Out:
# C:\Users\shunk\AppData\Local\Temp\ipykernel_27376\173575101.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=data.columns)
